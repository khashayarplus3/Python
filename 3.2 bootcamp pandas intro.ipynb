# %%
import pandas as pd
from pathlib import Path

# %%
csvpath= Path('/Users/khashayarzare/Desktop/bootcamp/3.2 panda py/01-Ins_Reading_CSVs/Resources/sales.csv')

# %%
salesdataframe= pd.read_csv(csvpath)

# %%
salesdataframe.head()
# Out:
#           FullName                   Email                   Address    Zip  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#             CreditCard  SalePrice
# 0  5327 0855 9720 7055      84.33
# 1    3717 498777 19636     879.95
# 2    3758 579477 35734     907.58
# 3  4400 0380 4162 1622     545.88
# 4    3712 263405 60178     517.49

# %%
rsalesdataframe.describe()
# Out:
#                 Zip   SalePrice
# count    100.000000  100.000000
# mean   40952.160000  533.007200
# std    30207.118496  275.531072
# min      555.000000   29.720000
# 25%    11109.750000  328.507500
# 50%    40033.500000  536.110000
# 75%    65834.750000  767.885000
# max    99877.000000  998.760000

# %%
csvpath1= Path('/Users/khashayarzare/Desktop/bootcamp/3.2 panda py/01-Ins_Reading_CSVs/Resources/sales_no_header.csv')

# %%
sales_dataframe_no_header= pd.read_csv(csvpath1, header=None)

# %%
sales_dataframe_no_header.head()
# Out:
#                  0                       1                         2      3  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#                      4       5
# 0  5327 0855 9720 7055   84.33
# 1    3717 498777 19636  879.95
# 2    3758 579477 35734  907.58
# 3  4400 0380 4162 1622  545.88
# 4    3712 263405 60178  517.49

# %%
columns=['Full name', 'Email','Address', 'Zipcode', 'Creditcard#', 'Salesprice']

# %%
sales_dataframe_no_header.columns= columns

# %%
sales_dataframe_no_header.head()
# Out:
#          Full name                    Email                   Address  \
# 0   Lyndon Elliott   arrowy1873@outlook.com          1234 Avery Plaza
# 1   Daisey Sellers   toucan2024@outlook.com         469 Elwood Street
# 2     Issac Reeves     asarin1958@gmail.com          565 Phelps Field
# 3  Bradford Kinney   mibound1801@yandex.com  853 Mission Rock Freeway
# 4     Fermina Cobb  kingfisher2013@live.com          929 Prague Trail
#
#    Zipcode          Creditcard#  Salesprice
# 0     1330    3717 498777 19636      879.95
# 1     7631    3758 579477 35734      907.58
# 2    81168  4400 0380 4162 1622      545.88
# 3    41721    3712 263405 60178      517.49
# 4    16625  2351 7156 8193 8639      889.95

# %%
import pandas as pd
from pathlib import Path
csvpath2= Path('/Users/khashayarzare/Desktop/bootcamp/panda-3.2-py/03-Ins_Columns/Resources/customers.csv')

# %%
costumers_df= pd.read_csv(csvpath2)

# %%
costumers_df.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'Balance'], dtype='object')

# %%
costumers_df.head(20)
# Out:
#                FullName                        Email                  Address  \
# 0       Altha Frederick     unhideable1966@gmail.com  67 John Maher Extension
# 1       Nickolas Harvey      allgood1803@outlook.com        1200 Madera Plaza
# 2       Jesusita Kinney       satsumas1954@yahoo.com         943 Gibb Highway
# 3           Mose Gordon       antifowl1875@gmail.com          1073 Fell Trace
# 4       Cesar Valentine     acetaminol1979@yahoo.com   805 Marshall Promenade
# 5          Erich Wooten     commanding1927@gmail.com        239 Mckinley Line
# 6           Elias Ayers         breeds1855@gmail.com      1109 Teresita Point
# 7       Boris Macdonald      pronounal1891@yahoo.com        641 Lexington Run
# 8           Emilio Bird   blacklegging1855@yahoo.com         222 Moulton Brae
# 9        Vincenza Patel      octachord1995@yahoo.com     1245 Whiting Parkway
# 10     Norberto Pollard      clarified1907@gmail.com        1362 Fulton Trace
# ...

# %%
costumers_df.rename(columns={"Full name": 'full name', 'Zip': 'Zip code'})
# Out:
#              FullName                     Email                    Address  \
# 0     Altha Frederick  unhideable1966@gmail.com    67 John Maher Extension
# 1     Nickolas Harvey   allgood1803@outlook.com          1200 Madera Plaza
# 2     Jesusita Kinney    satsumas1954@yahoo.com           943 Gibb Highway
# 3         Mose Gordon    antifowl1875@gmail.com            1073 Fell Trace
# 4     Cesar Valentine  acetaminol1979@yahoo.com     805 Marshall Promenade
# ..                ...                       ...                        ...
# 95     Crystle Larson     plantula1818@live.com  1317 Cesar Chavez On Brae
# 96    Jetta Davenport  doolittle1818@yandex.com       618 Williams Terrace
# 97    Dallas Johnston        mosso1961@live.com             324 Tenny Line
# 98  Roberto Daugherty    ovenful1914@yandex.com         1058 Marengo Manor
# 99       Abel Walters      esson1909@yandex.com           89 Rivera Bypass
#
#     Zip code           CreditCard  Balance  Balance(1K)
# ...

# %%
costumers_df["Balance(1K)"]= costumers_df["Balance"]/ 1000

# %%
import pandas as pd
from pathlib import Path
csvpath1= Path('/Users/khashayarzare/Desktop/bootcamp/3.2 panda py/01-Ins_Reading_CSVs/Resources/sales_no_header.csv')
costumers_df= pd.read_csv(csvpath1)
costumers_df1.rename(columns={"Full name": 'full name', 'Zip': 'Zip code'})
customers_df= costumers_df[["credit_card_number", 'Account_balance', 'fullname', 'email', 'address', 'Zipcode']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [10], in <cell line: 4>()
#       2 from pathlib import Path
#       3 csvpath1= Path('/Users/khashayarzare/Desktop/bootcamp/3.2 panda py/01-Ins_Reading_CSVs/Resources/sales_no_header.csv')
# ----> 4 costumers_df= pd.read_csv(csvpath1)
#       5 costumers_df1.rename(columns={"Full name": 'full name', 'Zip': 'Zip code'})
#       6 customers_df= costumers_df[["credit_card_number", 'Account_balance', 'fullname', 'email', 'address', 'Zipcode']]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# ...

# %%
names= costumers_df["full name"].str.split('',expand= True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 names= costumers_df["full name"].str.split('',expand= True)
#
# NameError: name 'costumers_df' is not defined

# %%
costumers_df.head()
# Out:
#           FullName                     Email                  Address    Zip  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension  31353
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza   1922
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway  41535
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace  16098
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade  99895
#
#             CreditCard  Balance  Balance(1K)
# 0  2524 2317 2139 4751    21511       21.511
# 1  4756 0997 9568 1329    13850       13.850
# 2    3717 863466 48574    21254       21.254
# 3  5413 1700 6989 2835     5221        5.221
# 4  5173 4883 9215 4743     8300        8.300
