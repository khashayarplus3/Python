# %%
from pathlib import Path
import pandas as pd

# %%
csvpath= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/01-Ins_Reading_CSVs/Resources/sales.csv")

# %%
sales_dataframe=pd.read_csv(csvpath) #write a dataframe

# %%
sales_dataframe.head(10)
# Out:
#           FullName                      Email                   Address  \
# 0    Elwanda White         alyre2036@live.com        352 Lakeshore Mall
# 1   Lyndon Elliott     arrowy1873@outlook.com          1234 Avery Plaza
# 2   Daisey Sellers     toucan2024@outlook.com         469 Elwood Street
# 3     Issac Reeves       asarin1958@gmail.com          565 Phelps Field
# 4  Bradford Kinney     mibound1801@yandex.com  853 Mission Rock Freeway
# 5     Fermina Cobb    kingfisher2013@live.com          929 Prague Trail
# 6  Merrill Andrews        beechy2059@live.com          41 Clarion Drive
# 7   Claris Pearson     kiwifruit2045@live.com          638 Lundeen Park
# 8  Georgiann Black  tattooage1863@outlook.com    1139 San Lorenzo Green
# 9     Carlos Hicks    lengthen1993@yandex.com       1218 Angelos Parade
#
#      Zip           CreditCard  SalePrice
# 0   9236  5327 0855 9720 7055      84.33
# 1   1330    3717 498777 19636     879.95
# 2   7631    3758 579477 35734     907.58
# ...

# %%
sales_dataframe.describe()
# Out:
#                 Zip   SalePrice
# count    100.000000  100.000000
# mean   40952.160000  533.007200
# std    30207.118496  275.531072
# min      555.000000   29.720000
# 25%    11109.750000  328.507500
# 50%    40033.500000  536.110000
# 75%    65834.750000  767.885000
# max    99877.000000  998.760000

# %%
csv_path1 = Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/01-Ins_Reading_CSVs/Resources/sales_no_header.csv")

# %%
sales_dataframe_no_header= pd.read_csv(csv_path1, header= None)

# %%
sales_dataframe_no_header.head()
# Out:
#                  0                       1                         2      3  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall   9236
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza   1330
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street   7631
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field  81168
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway  41721
#
#                      4       5
# 0  5327 0855 9720 7055   84.33
# 1    3717 498777 19636  879.95
# 2    3758 579477 35734  907.58
# 3  4400 0380 4162 1622  545.88
# 4    3712 263405 60178  517.49

# %%
columns= ["Full name", "email", "address","zip code","credit card #", "sales price" ]

# %%
sales_dataframe_no_header.columns= columns
sales_dataframe_no_header.head()
# Out:
#          Full name                   email                   address  \
# 0    Elwanda White      alyre2036@live.com        352 Lakeshore Mall
# 1   Lyndon Elliott  arrowy1873@outlook.com          1234 Avery Plaza
# 2   Daisey Sellers  toucan2024@outlook.com         469 Elwood Street
# 3     Issac Reeves    asarin1958@gmail.com          565 Phelps Field
# 4  Bradford Kinney  mibound1801@yandex.com  853 Mission Rock Freeway
#
#    zip code        credit card #  sales price
# 0      9236  5327 0855 9720 7055        84.33
# 1      1330    3717 498777 19636       879.95
# 2      7631    3758 579477 35734       907.58
# 3     81168  4400 0380 4162 1622       545.88
# 4     41721    3712 263405 60178       517.49

# %%
# Activity 1

# %%
stock_path=Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/02-Stu_Reading_CSVs/Resources/shopify_stock_data.csv")
stock_dataframe= pd.read_csv(stock_path)

# %%
stock_dataframe.head(10)
# Out:
#    5/21/2015 16:00:00  31.25  211058  35.03  35.03.1     30
# 0  5/22/2015 16:00:00  34.94  224174  32.32    38.00  32.00
# 1  5/25/2015 16:00:00  37.26  105460  35.00    37.47  35.00
# 2  5/26/2015 16:00:00  36.92   75935  37.26    37.69  36.30
# 3  5/27/2015 16:00:00  34.50  135778  38.00    38.16  33.63
# 4  5/28/2015 16:00:00  34.00   28756  34.60    34.60  33.14
# 5  5/29/2015 16:00:00  33.52   15319  33.71    34.11  33.35
# 6   6/1/2015 16:00:00  33.85    8839  33.73    34.27  33.52
# 7   6/2/2015 16:00:00  33.13    7318  34.72    34.72  33.13
# 8   6/3/2015 16:00:00  34.19   29821  33.98    34.26  33.00
# 9   6/4/2015 16:00:00  33.45   32221  34.99    34.99  31.88

# %%
#change the header column
columns= ["Date", "Close", "Volume", "Open", "High", "Low"]

stock_dataframe.columns= columns

# %%
stock_dataframe.head(10)
# Out:
#                  Date  Close  Volume   Open   High    Low
# 0  5/22/2015 16:00:00  34.94  224174  32.32  38.00  32.00
# 1  5/25/2015 16:00:00  37.26  105460  35.00  37.47  35.00
# 2  5/26/2015 16:00:00  36.92   75935  37.26  37.69  36.30
# 3  5/27/2015 16:00:00  34.50  135778  38.00  38.16  33.63
# 4  5/28/2015 16:00:00  34.00   28756  34.60  34.60  33.14
# 5  5/29/2015 16:00:00  33.52   15319  33.71  34.11  33.35
# 6   6/1/2015 16:00:00  33.85    8839  33.73  34.27  33.52
# 7   6/2/2015 16:00:00  33.13    7318  34.72  34.72  33.13
# 8   6/3/2015 16:00:00  34.19   29821  33.98  34.26  33.00
# 9   6/4/2015 16:00:00  33.45   32221  34.99  34.99  31.88

# %%
stock_dataframe.tail(10)
# Out:
#                      Date   Close  Volume    Open    High     Low
# 1144  12/13/2019 16:00:00  508.43  312817  488.94  516.60  488.90
# 1145  12/16/2019 16:00:00  517.42  221975  513.98  521.26  502.85
# 1146  12/17/2019 16:00:00  510.85  252381  517.20  521.97  500.77
# 1147  12/18/2019 16:00:00  520.56  391152  513.00  530.17  512.97
# 1148  12/19/2019 16:00:00  516.06  178895  520.99  526.66  513.85
# 1149  12/20/2019 16:00:00  513.22  715483  516.20  524.99  510.29
# 1150  12/23/2019 16:00:00  511.62  243940  516.83  524.99  510.37
# 1151  12/24/2019 13:30:00  525.39  125214  512.46  527.17  508.21
# 1152  12/27/2019 16:00:00  534.76  156355  539.97  544.00  528.00
# 1153  12/30/2019 16:00:00  517.79  162031  535.36  535.36  512.57

# %%
#instructions 2

# %%
csv_path2=Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/03-Ins_Columns/Resources/customers.csv")

# %%
customers_df= pd.read_csv(csv_path2)
customers_df.head(10)
# Out:
#           FullName                       Email                  Address  \
# 0  Altha Frederick    unhideable1966@gmail.com  67 John Maher Extension
# 1  Nickolas Harvey     allgood1803@outlook.com        1200 Madera Plaza
# 2  Jesusita Kinney      satsumas1954@yahoo.com         943 Gibb Highway
# 3      Mose Gordon      antifowl1875@gmail.com          1073 Fell Trace
# 4  Cesar Valentine    acetaminol1979@yahoo.com   805 Marshall Promenade
# 5     Erich Wooten    commanding1927@gmail.com        239 Mckinley Line
# 6      Elias Ayers        breeds1855@gmail.com      1109 Teresita Point
# 7  Boris Macdonald     pronounal1891@yahoo.com        641 Lexington Run
# 8      Emilio Bird  blacklegging1855@yahoo.com         222 Moulton Brae
# 9   Vincenza Patel     octachord1995@yahoo.com     1245 Whiting Parkway
#
#      Zip           CreditCard  Balance
# 0  31353  2524 2317 2139 4751    21511
# 1   1922  4756 0997 9568 1329    13850
# 2  41535    3717 863466 48574    21254
# ...

# %%
customers_df.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'Balance'], dtype='object')

# %%
customers_df.head(10)
# Out:
#           FullName                       Email                  Address  \
# 0  Altha Frederick    unhideable1966@gmail.com  67 John Maher Extension
# 1  Nickolas Harvey     allgood1803@outlook.com        1200 Madera Plaza
# 2  Jesusita Kinney      satsumas1954@yahoo.com         943 Gibb Highway
# 3      Mose Gordon      antifowl1875@gmail.com          1073 Fell Trace
# 4  Cesar Valentine    acetaminol1979@yahoo.com   805 Marshall Promenade
# 5     Erich Wooten    commanding1927@gmail.com        239 Mckinley Line
# 6      Elias Ayers        breeds1855@gmail.com      1109 Teresita Point
# 7  Boris Macdonald     pronounal1891@yahoo.com        641 Lexington Run
# 8      Emilio Bird  blacklegging1855@yahoo.com         222 Moulton Brae
# 9   Vincenza Patel     octachord1995@yahoo.com     1245 Whiting Parkway
#
#      Zip           CreditCard  Balance
# 0  31353  2524 2317 2139 4751    21511
# 1   1922  4756 0997 9568 1329    13850
# 2  41535    3717 863466 48574    21254
# ...

# %%
#renaming a column or columns 
customers_df = customers_df.rename(columns ={"FullName": "full name", "CreditCard": "credit_card_number"})

# %%
customers_df.head()
# Out:
#          full name                     Email                  Address    Zip  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension  31353
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza   1922
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway  41535
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace  16098
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade  99895
#
#     credit_card_number  Balance
# 0  2524 2317 2139 4751    21511
# 1  4756 0997 9568 1329    13850
# 2    3717 863466 48574    21254
# 3  5413 1700 6989 2835     5221
# 4  5173 4883 9215 4743     8300

# %%
#create a new column
customers_df["balance (1)k"]= customers_df["Balance"]/ 1000

# %%
# split a column
names= customers_df["full name"].str.split(" ", expand= True)

# %%
names.head()
# Out:
#           0          1
# 0     Altha  Frederick
# 1  Nickolas     Harvey
# 2  Jesusita     Kinney
# 3      Mose     Gordon
# 4     Cesar  Valentine

# %%
customers_df.head(5)
# Out:
#          full name                     Email                  Address    Zip  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension  31353
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza   1922
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway  41535
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace  16098
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade  99895
#
#     credit_card_number  Balance  balance (1)k
# 0  2524 2317 2139 4751    21511        21.511
# 1  4756 0997 9568 1329    13850        13.850
# 2    3717 863466 48574    21254        21.254
# 3  5413 1700 6989 2835     5221         5.221
# 4  5173 4883 9215 4743     8300         8.300

# %%
customers_df["first name"]= names[0]
customers_df["Last name"]=names[1]

# %%
#drop column
customers_df.drop(columns= "full name")
# Out:
#                        Email                    Address    Zip  \
# 0   unhideable1966@gmail.com    67 John Maher Extension  31353
# 1    allgood1803@outlook.com          1200 Madera Plaza   1922
# 2     satsumas1954@yahoo.com           943 Gibb Highway  41535
# 3     antifowl1875@gmail.com            1073 Fell Trace  16098
# 4   acetaminol1979@yahoo.com     805 Marshall Promenade  99895
# ..                       ...                        ...    ...
# 95     plantula1818@live.com  1317 Cesar Chavez On Brae  74413
# 96  doolittle1818@yandex.com       618 Williams Terrace  73152
# 97        mosso1961@live.com             324 Tenny Line  88215
# 98    ovenful1914@yandex.com         1058 Marengo Manor  33903
# 99      esson1909@yandex.com           89 Rivera Bypass  39186
#
#      credit_card_number  Balance  balance (1)k first name  Last name
# 0   2524 2317 2139 4751    21511        21.511      Altha  Frederick
# 1   4756 0997 9568 1329    13850        13.850   Nickolas     Harvey
# ...

# %%
#ins 04 Data cleaning 

csvpath3= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/04-Ins_Data_Cleaning/Resources/order_data.csv")

# %%
csv_data= pd.read_csv(csvpath3, index_col="order_no")

# %%
#sample datapoints 
csv_data.sample(5)
# Out:
#            customer_no order_total  order_date
# order_no
# 45235825        TV4663       65.42  04-29-2019
# 45251825      CJ458565       14.00  04/25/2019
# 4465241327     AK45765    $1103.36  04-25-2019
# 4465241327     AK45765    $1103.36  04-25-2019
# 413853121     CM458565         NaN   4/24/2019

# %%
#data types 
csv_data.dtypes
# Out:
# customer_no    object
# order_total    object
# order_date     object
# dtype: object

# %%
csv_data.count()
# Out:
# customer_no    7
# order_total    7
# order_date     8
# dtype: int64

# %%
#find unique values 
csv_data["customer_no"].value_counts()
# Out:
# CM458565    2
# AK45765     2
# CJ458565    1
# TV4663      1
# 2124        1
# Name: customer_no, dtype: int64

# %%
#check the number of empty cells
csv_data.isnull()
# Out:
#             customer_no  order_total  order_date
# order_no
# 452517125         False        False       False
# 45251825          False        False       False
# 4465241327        False        False       False
# 4465241327        False        False       False
# 413853121         False         True       False
# 45235825          False        False       False
# 2356363           False        False       False
# 452519232          True        False       False

# %%
csv_data["customer_no"]= csv_data["customer_no"].fillna("Unknown")

# %%
#drops a row with null value in it 
csv_data= csv_data.dropna().copy()
csv_data
# Out:
#            customer_no order_total  order_date
# order_no
# 452517125     CM458565     $141.25  01-10-2019
# 45251825      CJ458565       14.00  04/25/2019
# 4465241327     AK45765    $1103.36  04-25-2019
# 4465241327     AK45765    $1103.36  04-25-2019
# 45235825        TV4663       65.42  04-29-2019
# 2356363           2124   258936.12  04-29-2019
# 452519232      Unknown     $141.25  01-10-2019

# %%
csv_data.drop_duplicates().copy()
# Out:
#            customer_no order_total  order_date
# order_no
# 452517125     CM458565     $141.25  01-10-2019
# 45251825      CJ458565       14.00  04/25/2019
# 4465241327     AK45765    $1103.36  04-25-2019
# 45235825        TV4663       65.42  04-29-2019
# 2356363           2124   258936.12  04-29-2019
# 452519232      Unknown     $141.25  01-10-2019

# %%
csv_data["order_total"]=csv_data["order_total"].str.replace("$", "")
csv_data["order_total"]
# Out:
# /var/folders/kl/j44n1f9551gb0b57c2h4xbh40000gn/T/ipykernel_2381/3066712885.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   csv_data["order_total"]=csv_data["order_total"].str.replace("$", "")
# order_no
# 452517125        141.25
# 45251825          14.00
# 4465241327      1103.36
# 4465241327      1103.36
# 45235825          65.42
# 2356363       258936.12
# 452519232        141.25
# Name: order_total, dtype: object

# %%
csv_data["order_total"] = csv_data["order_total"].astype("float")

# %%
csv_data.dtypes

# %%
#05 activity Spring Cleaning

It's that time of year again: the end of the fiscal year and the time to begin financial spring cleaning! Within a month, auditors will be camped out at your investment firm, inspecting everyone's trades and the company's end-of-year financial statements. All of the firm's traders are under a lot of pressure to finalize their portfolio earnings and deliver them to their managers. That is, all traders except you.

You automated your end-of-year financial reporting last week, and now you're using the pipeline to help Harold with his reports. Before loading Harold's stock ticker data into Pandas, you open the Excel file he sent you to look at the quality of the data. You realize that Harold has not subscribed to any data quality standards and that the data is a mess.

For this activity, use Pandas to clean Harold's portfolio data to get it fit for use.

## Instructions

Using the [starter file](Unsolved/spring_cleaning.ipynb) and Harold's financial [data](Resources/stock_data.csv), complete the following steps.

1. Load CSV data into Pandas using `read_csv`.
csv_path= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/05-Stu_Data_Cleaning/Resources/stock_data.csv")
 

2. Identify the number of rows and columns in the DataFrame, otherwise known as its shape/structure.

3. Preview the DataFrame using `head` to visually ensure data has been loaded in correctly.

4. Identify the number of records in the DataFrame, and compare it with the number of rows in the original file.

5. Identify null records by calculating average percent of nulls for each Series. **Hint:** This step will require the `mean` function.

6. Drop null records.

7. Validate all nulls have been dropped by calculating the `sum` of values that are null.

8. Default null `ebitda` values to 0.

9. Check that there are no null `ebitda` values using the `sum` function.

10. Remove duplicate rows.

## Challenge

Now that nulls and duplicates have been wrangled, clean up the data a little more by removing the `$` currency symbols from the `price` field. Then, use the `astype` function to cast `price` to a `float`, and validate using `dtype`.

## Hint

Pandas offers a `replace` function that can be executed against a Series. Documentation can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html).

---

© 2020 Trilogy Education Services, a 2U, Inc. brand. All Rights Reserved.

# %%
csv_path= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/05-Stu_Data_Cleaning/Resources/stock_data.csv")
csv_data=pd.read_csv(csv_path)
csv_data.head()
# Out:
#   symbol                 name                  sector    price  \
# 0    MMM           3M Company             Industrials  $222.89
# 1    AOS      A.O. Smith Corp             Industrials      NaN
# 2    ABT  Abbott Laboratories             Health Care    56.27
# 3   ABBV          AbbVie Inc.             Health Care   108.48
# 4   ATVI  Activision Blizzard  Information Technology    65.83
#
#    price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0               24.31        2.332862              $7.92      259.770
# 1                 NaN             NaN                NaN          NaN
# 2               22.51        1.908982               0.26       64.600
# 3               19.41        2.499560               3.29      125.860
# 4                 NaN        0.431903               1.28       74.945
#
#    52_week_high    market_cap        ebitda  price_per_sales  price_per_book  \
# 0        175.49  1.387211e+11  9.048000e+09         4.390271           11.34
# ...

# %%
nan_count= csv_data.isna().sum().sum()
mean_df=nan_count/ 14
mean_df
# Out:
# 5.071428571428571

# %%
csv_data.shape
csv_data.dropna()
# Out:
#     symbol                    name                  sector    price  \
# 0      MMM              3M Company             Industrials  $222.89
# 2      ABT     Abbott Laboratories             Health Care    56.27
# 3     ABBV             AbbVie Inc.             Health Care   108.48
# 5      AYI       Acuity Brands Inc             Industrials   108.48
# 6     ADBE       Adobe Systems Inc  Information Technology   185.16
# ..     ...                     ...                     ...      ...
# 499    XYL              Xylem Inc.             Industrials    70.24
# 500    YUM         Yum! Brands Inc  Consumer Discretionary     76.3
# 501    ZBH  Zimmer Biomet Holdings             Health Care   115.53
# 502   ZION           Zions Bancorp              Financials    50.71
# 503    ZTS                  Zoetis             Health Care    71.51
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0                 24.31        2.332862              $7.92       259.77
# ...

# %%
csv_data.columns
# Out:
# Index(['symbol', 'name', 'sector', 'price', 'price_per_earnings',
#        'dividend_yield', 'earnings_per_share', '52_week_low', '52_week_high',
#        'market_cap', 'ebitda', 'price_per_sales', 'price_per_book',
#        'sec_filings'],
#       dtype='object')

# %%
columns= csv_data.columns

# %%
csv_data.dtypes
# Out:
# symbol                 object
# name                   object
# sector                 object
# price                  object
# price_per_earnings    float64
# dividend_yield        float64
# earnings_per_share     object
# 52_week_low           float64
# 52_week_high          float64
# market_cap            float64
# ebitda                float64
# price_per_sales       float64
# price_per_book        float64
# sec_filings            object
# dtype: object

# %%
csv_path4= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/06-Ins_Indexing/Resources/people.csv")
people_csv= pd.read_csv(csv_path4)

# %%
people_csv.describe(include= "all")
# Out:
#        first_name last_name gender         age      company_name  \
# count         500       500    500  500.000000               500
# unique        479       498      2         NaN               498
# top       Antonio     Rampy      F         NaN  Martin Morrissey
# freq            3         2    301         NaN                 2
# mean          NaN       NaN    NaN   42.130000               NaN
# std           NaN       NaN    NaN   10.702625               NaN
# min           NaN       NaN    NaN   24.000000               NaN
# 25%           NaN       NaN    NaN   33.000000               NaN
# 50%           NaN       NaN    NaN   43.000000               NaN
# 75%           NaN       NaN    NaN   52.000000               NaN
# max           NaN       NaN    NaN   60.000000               NaN
#
#              address                   city          county   postal  \
# count            500                    500             500      500
# ...

# %%
#gives info about the second and third row 
people_csv.iloc[1:3]
# Out:
#   first_name  last_name gender  age         company_name       address  \
# 1       Evan  Zigomalas      M   47   Cap Gemini America   5 Binney St
# 2     France    Andrade      M   42  Elliott, John W Esq  8 Moor Place
#
#                              city           county    postal        phone1  \
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
#
#          phone2                       email                                web
# 1  01714-737668    evan.zigomalas@gmail.com  http://www.capgeminiamerica.co.uk
# 2  01935-821636  france.andrade@hotmail.com   http://www.elliottjohnwesq.co.uk

# %%
people_csv.iloc[0]
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# gender                                             F
# age                                               54
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: 0, dtype: object

# %%
people_csv.head()
# Out:
#   first_name   last_name gender  age             company_name  \
# 0    Aleshia  Tomkiewicz      F   54  Alan D Rosenburg Cpa Pc
# 1       Evan   Zigomalas      M   47       Cap Gemini America
# 2     France     Andrade      M   42      Elliott, John W Esq
# 3    Ulysses   Mcwalters      M   45           Mcmahan, Ben L
# 4     Tyisha      Veness      F   37           Champagne Room
#
#              address                            city           county  \
# 0       14 Taylor St               St. Stephens Ward             Kent
# 1        5 Binney St                      Abbey Ward  Buckinghamshire
# 2       8 Moor Place  East Southbourne and Tuckton W      Bournemouth
# 3      505 Exeter Rd              Hawerby cum Beesby     Lincolnshire
# 4  5396 Forth Street      Greets Green and Lyng Ward    West Midlands
#
#      postal        phone1        phone2                       email  \
# 0   CT2 7PP  01835-703597  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
people_csv.iloc[:,0].head()
# Out:
# 0    Aleshia
# 1       Evan
# 2     France
# 3    Ulysses
# 4     Tyisha
# Name: first_name, dtype: object

# %%
#print last column
people_csv.iloc[:,-1].head()
# Out:
# 0    http://www.alandrosenburgcpapc.co.uk
# 1       http://www.capgeminiamerica.co.uk
# 2        http://www.elliottjohnwesq.co.uk
# 3            http://www.mcmahanbenl.co.uk
# 4          http://www.champagneroom.co.uk
# Name: web, dtype: object

# %%
#print 4 rows and 3 columns
people_csv.iloc[0:5, 2:5]
# Out:
#   gender  age             company_name
# 0      F   54  Alan D Rosenburg Cpa Pc
# 1      M   47       Cap Gemini America
# 2      M   42      Elliott, John W Esq
# 3      M   45           Mcmahan, Ben L
# 4      F   37           Champagne Room

# %%
people_csv.iloc[0, people_csv.columns.get_loc("first_name")]= "Arya"
people_csv.iloc[0]
# Out:
# first_name                                      Arya
# last_name                                 Tomkiewicz
# gender                                             F
# age                                               54
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# Name: 0, dtype: object

# %%
people_csv
# Out:
#     first_name   last_name gender  age                    company_name  \
# 0         Arya  Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas      M   47              Cap Gemini America
# 2       France     Andrade      M   42             Elliott, John W Esq
# 3      Ulysses   Mcwalters      M   45                  Mcmahan, Ben L
# 4       Tyisha      Veness      F   37                  Champagne Room
# ..         ...         ...    ...  ...                             ...
# 495      Avery        Veit      M   38      Plaza Gourmet Delicatessen
# 496       Reid     Euresti      M   56            Fitzgerald, Edward J
# 497  Charlette    Brenning      F   31              Furey & Associates
# 498  Celestina       Keeny      F   41        Bfg Federal Credit Union
# 499         Mi      Richan      M   27  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# ...

# %%
people_csv = people_csv.sort_index()

# %%
people_csv
# Out:
#     first_name   last_name gender  age                    company_name  \
# 0         Arya  Tomkiewicz      F   54         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas      M   47              Cap Gemini America
# 2       France     Andrade      M   42             Elliott, John W Esq
# 3      Ulysses   Mcwalters      M   45                  Mcmahan, Ben L
# 4       Tyisha      Veness      F   37                  Champagne Room
# ..         ...         ...    ...  ...                             ...
# 495      Avery        Veit      M   38      Plaza Gourmet Delicatessen
# 496       Reid     Euresti      M   56            Fitzgerald, Edward J
# 497  Charlette    Brenning      F   31              Furey & Associates
# 498  Celestina       Keeny      F   41        Bfg Federal Credit Union
# 499         Mi      Richan      M   27  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# ...

# %%
#Ins 06 - the full python file is in the bootcamp dowloaded page

# %%
#7 Activity

# %%
'''# Three-Year Loans

The higher-ups at Harold's firm want to know how to better target customers who are seeking three-year loans. Harold's manager has asked him to review a compilation of loan data, and then filter out the necessary data to generate insights about customers who have been granted three-year loans.

Follow the instructions to help Harold answer his manager's questions.

## Instructions

Complete the following steps.

1. Import the necessary libraries and dependencies.

2. Read in the `loans.csv` data into a Pandas DataFrame.

3. Show the first `10` records of the data.

4. View summary statistics for the `loans.csv` data.

5. Create a subset DataFrame `filtered_df` by filtering the columns so that only the following columns remain:

    * `loan_amnt`
    * `term`
    * `int_rate`
    * `emp_title`
    * `annual_inc`
    * `purpose`

6. Filter `filtered_df` by row values where `term` is equal to `36 months` in order to focus on three-year loan records only.

7. Modify rows with `term` values equal to `36 months` to be `3 years`.

8. Use the `isnull()` function to modify rows with `emp_title` values equal to `NaN` to be `Unknown`.

9. View summary statistics for `term_df` after all modifications.

10. Use the `value_counts()` function on the `emp_title` column of the `term_df` DataFrame to see the unique value counts for employee titles of three-year loan customers.

11. Use the `value_counts()` function on the `purpose` column of the `term_df` DataFrame to see the unique value counts for loan purposes of three-year loan customers.

12. Filter `term_df` by rows with `annual_inc` greater than `80000`. Use the `mean()` function to see the average `int_rate` of three-year loan customers with annual incomes greater than $80,000.

13. Filter `term_df` by rows with `annual_inc` less than `80000`. Use the `mean()` function to see the average `int_rate` of three-year loan customers with annual incomes less than $80,000.

14. Help Harold answer the following questions for his manager:

    * What kind of customers (employee title) seem to ask for three-year loans most frequently?

    * What are three-year loans generally used for?

    * What is the difference between counts of three-year loan customers with annual incomes greater than `$80,000`, compared to those with annual incomes less than `$80,000`?

    * What is the difference between interest rates for customers with annual incomes greater than `$80,000` compared to those with annual incomes less than `$80,000`?

## Hint

View the [Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/) for additional explanations about using specific functions.

---

© 2020 Trilogy Education Services, a 2U, Inc. brand. All Rights Reserved.'''
# Out:
#   Input In [66]
#     The higher-ups at Harold's firm want to know how to better target customers who are seeking three-year loans. Harold's manager has asked him to review a compilation of loan data, and then filter out the necessary data to generate insights about customers who have been granted three-year loans.
#         ^
# SyntaxError: invalid syntax

# %%
csv_path5= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/07-Stu_Indexing/Resources/loans.csv")

# %%
loans_df=pd.read_csv(csv_path5, low_memory=False)

# %%
'''3. Show the first `10` records of the data.

4. View summary statistics for the `loans.csv` data.

5. Create a subset DataFrame `filtered_df` by filtering the columns so that only the following columns remain:

    * `loan_amnt`
    * `term`
    * `int_rate`
    * `emp_title`
    * `annual_inc`
    * `purpose`
'''
# Out:
# '3. Show the first `10` records of the data.\n\n4. View summary statistics for the `loans.csv` data.\n\n5. Create a subset DataFrame `filtered_df` by filtering the columns so that only the following columns remain:\n\n    * `loan_amnt`\n    * `term`\n    * `int_rate`\n    * `emp_title`\n    * `annual_inc`\n    * `purpose`\n'

# %%
loans_df.head(10)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 1       4000         4000           4000.0  36 months    0.2340       155.68
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 3       9600         9600           9600.0  36 months    0.1298       323.37
# 4       2500         2500           2500.0  36 months    0.1356        84.92
# 5      30000        30000          30000.0  60 months    0.1894       777.23
# 6      23000        23000          23000.0  60 months    0.2089       620.81
# 7      32075        32075          32075.0  60 months    0.1180       710.26
# 8       8000         8000           8000.0  36 months    0.2340       311.35
# 9      10000        10000          10000.0  60 months    0.1992       264.50
#
#   grade sub_grade           emp_title emp_length home_ownership annual_inc  \
# ...

# %%
loans_df.describe()
# Out:
#            loan_amnt    funded_amnt  funded_amnt_inv       int_rate  \
# count  128412.000000  128412.000000    128412.000000  128412.000000
# mean    15971.321021   15971.321021     15968.498166       0.129302
# std     10150.384233   10150.384233     10152.168970       0.050904
# min      1000.000000    1000.000000       725.000000       0.060000
# 25%      8000.000000    8000.000000      8000.000000       0.084600
# 50%     14000.000000   14000.000000     14000.000000       0.118000
# 75%     21600.000000   21600.000000     21600.000000       0.161400
# max     40000.000000   40000.000000     40000.000000       0.309900
#
#          installment
# count  128412.000000
# mean      463.259353
# std       285.718256
# min        30.480000
# 25%       253.630000
# 50%       382.905000
# 75%       622.680000
# max      1618.240000

# %%
filtered_df= ['loan_amnt', 'term', 'int_rate', 'emp_title', 'annual_inc', 'purpose']

# %%
#ins -8
csv_path6= Path('/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/08-Ins_Pandas_Visualization/Resources/annual_gold.csv')

# %%
gold_csv=pd.read_csv(csv_path6)

# %%
gold_csv.plot()
# Out:
# <AxesSubplot:>

# %%
gold_csv= gold_csv.set_index(pd.to_datetime(gold_csv["Date"], infer_datetime_format=True))

# %%
gold_csv.head()
# Out:
#                Date  Price
# Date
# 1950-12-01  1950-12  34.72
# 1951-12-01  1951-12  34.66
# 1952-12-01  1952-12  34.79
# 1953-12-01  1953-12  34.85
# 1954-12-01  1954-12  35.04

# %%
gold_csv.drop(columns= ["Date"])
# Out:
#                Price
# Date
# 1950-12-01    34.720
# 1951-12-01    34.660
# 1952-12-01    34.790
# 1953-12-01    34.850
# 1954-12-01    35.040
# ...              ...
# 2014-12-01  1200.440
# 2015-12-01  1068.317
# 2016-12-01  1152.165
# 2017-12-01  1265.674
# 2018-12-01  1249.887
#
# [69 rows x 1 columns]

# %%
gold_csv.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gold_csv.plot(kind='bar', figsize= (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Activity 09

# %%
csv_path7= Path('/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/09-Stu_Pandas_Visualization/Resources/sp500_companies.csv')

# %%
sp_df= pd.read_csv(csv_path7)

# %%
# Count the frequency of each sector from the list of companiesse
sector_df= sp_df['Sector'].value_counts()
print(sector_df)
# Out:
# Consumer Discretionary        84
# Information Technology        70
# Financials                    68
# Industrials                   67
# Health Care                   61
# Consumer Staples              34
# Real Estate                   33
# Energy                        32
# Utilities                     28
# Materials                     25
# Telecommunication Services     3
# Name: Sector, dtype: int64

# %%
sector_df.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Sector'>

# %%
# Plot a pie chart from the distribution of company sectors
# Grab the `Symbol` and `Market Cap` columns
market_cap=sp_df.loc[:, ["Symbol", "Market Cap"]]

# Set the 'Symbol' as the index
market_cap.set_index(market_cap["Symbol"], inplace=True)
# Drop the extra 'Symbol' column

market_cap.drop(columns= ["Symbol"], inplace= True)

# Filter down to 20 companies with the largest market caps
top_20= market_cap.nlargest(20, "Market Cap")
# Display the DataFrame
top_20
# Out:
#           Market Cap
# Symbol
# AAPL    809508034020
# GOOGL   733823966137
# GOOG    728535558140
# MSFT    689978437468
# AMZN    685873374731
# FB      523423036576
# JPM     386613611000
# JNJ     353062464971
# XOM     326148660000
# BAC     321478200969
# WMT     304680931618
# WFC     281463620775
# V       270038723213
# BRK.B   261401203633
# T       226713270000
# HD      223378633329
# CVX     218978820159
# UNH     218834811333
# INTC    211536000000
# PFE     208505541949

# %%
# Plot a bar chart of the top 20 market cap companies
top_20.plot(kind="bar", title=" top20")
# Out:
# <AxesSubplot:title={'center':' top20'}, xlabel='Symbol'>

# %%
# Plot a scatter plot to display the relationship between price vs. earnings/share
sp_df.plot(kind="scatter", x ="Earnings/Share", y="Price")
# Out:
# <AxesSubplot:xlabel='Earnings/Share', ylabel='Price'>

# %%
csvpath7= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/10-Ins_Returns/Resources/TSX_Data.csv")

# %%
tsx_csv= pd.read_csv(csvpath7)
tsx_csv.head()
# Out:
#                 Date      Open      High       Low     Close  Adj Close  \
# 0  1/4/2010 16:00:00  11847.34  11872.15  11746.11  11866.90   11866.90
# 1  1/5/2010 16:00:00  11900.01  11935.24  11837.23  11888.08   11888.08
# 2  1/6/2010 16:00:00  11912.88  11971.62  11888.08  11944.54   11944.54
# 3  1/7/2010 16:00:00  11925.03  11944.54  11819.50  11887.51   11887.51
# 4  1/8/2010 16:00:00  11883.26  11953.83  11863.13  11953.83   11953.83
#
#       Volume
# 0  132670512
# 1  167798256
# 2  194400880
# 3  190573664
# 4  167761216

# %%
tsx_csv= tsx_csv.set_index(pd.to_datetime(tsx_csv["Date"], infer_datetime_format=True))

# %%
tsx_csv=tsx_csv.drop(columns= ["Open", "High", "Low", "Close", "Volume"])

# %%
#tsx_csv= tsx_csv.drop(columns= ["Date"])

# %%
tsx_csv.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
daily_returns= (tsx_csv- tsx_csv.shift(1))/ tsx_csv
daily_returns.head()
# Out:
#                      Adj Close
# Date
# 2010-01-04 16:00:00        NaN
# 2010-01-05 16:00:00   0.001782
# 2010-01-06 16:00:00   0.004727
# 2010-01-07 16:00:00  -0.004797
# 2010-01-08 16:00:00   0.005548

# %%
daily_returns.plot(figsize= (10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
daily_returns= tsx_csv.pct_change()

# %%
cumulative_returns= (1+ daily_returns).cumprod()
cumulative_returns.head()
# Out:
#                      Adj Close
# Date
# 2010-01-04 16:00:00        NaN
# 2010-01-05 16:00:00   1.001785
# 2010-01-06 16:00:00   1.006543
# 2010-01-07 16:00:00   1.001737
# 2010-01-08 16:00:00   1.007325

# %%
cumulative_returns.plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Activity 11 Shopify

# %%
csvpath8= Path("/Users/khashayarzare/Desktop/Carleton University/bootcamp/python3.2/11-Stu_Returns/Resources/shopify_stock_data.csv")

# %%
shop_csv=pd.read_csv(csvpath8)

# %%
shop_csv.describe()
# Out:
#              close        volume         open         high          low
# count  1155.000000  1.155000e+03  1155.000000  1155.000000  1155.000000
# mean    158.939030  2.447068e+05   158.782268   161.897212   155.624459
# std     131.610276  3.170294e+05   131.419657   133.989183   128.882484
# min      26.810000  4.341000e+03    27.030000    27.380000    25.850000
# 25%      47.220000  7.211100e+04    47.465000    48.730000    45.465000
# 50%     127.110000  2.031930e+05   126.940000   129.310000   123.750000
# 75%     203.415000  3.230220e+05   205.050000   209.340000   200.000000
# max     541.490000  5.829405e+06   540.620000   544.000000   529.500000

# %%
shop_csv= shop_csv.drop(columns= ["volume", "open", "high", "low"])

# %%
shop_csv= shop_csv.set_index(pd.to_datetime(shop_csv["date"], infer_datetime_format=True))
shop_csv.head()
# Out:
#                                    date  close
# date
# 2015-05-21 16:00:00  5/21/2015 16:00:00  31.25
# 2015-05-22 16:00:00  5/22/2015 16:00:00  34.94
# 2015-05-25 16:00:00  5/25/2015 16:00:00  37.26
# 2015-05-26 16:00:00  5/26/2015 16:00:00  36.92
# 2015-05-27 16:00:00  5/27/2015 16:00:00  34.50

# %%
shop_csv= shop_csv.drop(columns= ["date"])

# %%
daily_returns= (shop_csv- shop_csv.shift(1))/ shop_csv
daily_returns.head()
# Out:
#                         close
# date
# 2015-05-21 16:00:00       NaN
# 2015-05-22 16:00:00  0.105610
# 2015-05-25 16:00:00  0.062265
# 2015-05-26 16:00:00 -0.009209
# 2015-05-27 16:00:00 -0.070145

# %%
returns_year1= shop_csv["date"].loc("2015-05-22":"2016-05-22")
# Out:
#   Input In [16]
#     returns_year1= shop_csv["date"].loc("2015-05-22":"2016-05-22")
#                                                     ^
# SyntaxError: invalid syntax
